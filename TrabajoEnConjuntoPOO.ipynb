# %% [markdown]
# <a href="https://colab.research.google.com/github/jgilhe/POO-UnalMed/blob/main/TrabajoEnConjuntoPOO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este es un colab realizado por Evelyn Pareja Ríos y  Juliana Gil Hernandez. Donde encontraran los ejercicios propuestos en la asignatura de Progración Orientada a Objetos (POO).

# %% [markdown]
# # <font color=#B375E6 size=6>**Ejercicio 2.1. Definicion de clases**</font>

# %% [markdown]
# Se requiere un programa que modele el concepto de una persona. Una persona posee nombre, apellido, número de documento de identidad y año de nacimiento. La clase debe tener un constructor que inicialice los valores de sus respectivos atributos.
#
# La clase debe incluir los siguientes métodos:
#
#
#
# *   Definir un método que imprima en pantalla los valores de los atributos del objeto.
# *   En un método main se deben crear dos personas y mostrar los valores de sus atributos en pantalla.

# %%
class Persona:
  def __init__(self, nombre, apellido, DI, ano_nacimiento):
    self.nombre = nombre
    self.apellido = apellido
    self.DI = DI
    self.ano_nacimiento = ano_nacimiento

# input para persona 1
print("Datos para la primera persona:")
nombre1 = input("Nombre: ")
apellido1 = input("Apellido: ")
DI1 = int(input("Documento de identidad: "))
ano_nacimiento1 = int(input("Año de nacimiento: "))
p1 = Persona(nombre1, apellido1, DI1, ano_nacimiento1)

# input para persona 2
print("\nDatos para la segunda persona:")
nombre2 = input("Nombre: ")
apellido2 = input("Apellido: ")
DI2 = int(input("Documento de identidad: "))
ano_nacimiento2 = int(input("Año de nacimiento: "))
p2 = Persona(nombre2, apellido2, DI2, ano_nacimiento2)
# Out:
# Datos para la primera persona:
# Nombre: Pedro
# Apellido: Perez
# Documento de identidad: 1053121010
# Año de nacimiento: 1998
#
# Datos para la segunda persona:
# Nombre: Luis
# Apellido: León
# Documento de identidad: 1053223344
# Año de nacimiento: 2001

# %% [markdown]
# # <font color=#B375E6 size=6>**Ejercicio 2.2. Definición de atributos de una clase con tipos primitivos de datos**</font>

# %% [markdown]
# Se requiere un programa que modele el concepto de un planeta del sistema solar. Un planeta tiene los siguientes atributos:
#
#
#
# *   Un nombre de tipo Sring con valor inicial de null
# *   Cantidad de satélites de tipo int con valor inicial de cero.
# *   Masa en kilogramos de tipo double con valor inicial de cero.
# * Volumen en kilómetros cúbicos de tipo double con valor inicial de cero.
# * Diámetro en kilómetros de tipo int con valor inicial de cero.
# * Distancia media al Sol en millones de kilómetros, de tipo int con valor inicial de cero.
# * Tipo de planeta de acuerdo con su tamaño, de tipo enumerado con los siguientes valores posibles: GASEOSO, TERRESTRE y ENANO.
# * Observable a simple vista, de tipo booleano con valor inicial false.
#
# La clase debe incluir los siguientes métodos:
#
# * La clase debe tener un constructor que inicialice los valores de sus respectivos atributos.
# *  Definir un método que imprima en pantalla los valores de los atributos de un planeta.
# * Calcular la densidad un planeta, como el cociente entre su masa y su volumen.
# * Determinar si un planeta del sistema solar se considera exterior. Un planeta exterior está situado más allá del cinturón de asteroides. El cinturón de asteroides se encuentra entre 2.1 y 3.4 UA. Una unidad astronómica (UA) es la distancia entre la Tierra y el Sol= 149 597 870 Km.
# * En un método main se deben crear dos planetas y mostrar los valores de sus atributos en pantalla. Además, se debe imprimir la densidad de cada planeta y si el planeta es un planeta exterior del sistema solar.

# %%
from enum import Enum

class TipoPlaneta(Enum):
    GASEOSO = 1
    TERRESTRE = 2
    ENANO = 3


class Planeta:

    UA = 149_597_870  # 1 Unidad Astronómica en km

    def __init__(self, nombre=None, cantidad_satelites=0, masa=0.0,
                 volumen=0.0, diametro=0, distancia_sol=0,
                 tipo_planeta=None, es_observable=False):

        self.nombre = nombre
        self.cantidad_satelites = cantidad_satelites
        self.masa = masa
        self.volumen = volumen
        self.diametro = diametro
        self.distancia_sol = distancia_sol
        self.tipo_planeta = tipo_planeta
        self.es_observable = es_observable

    def imprimir(self):
        print(f"\nPlaneta: {self.nombre}")
        print(f"Satélites: {self.cantidad_satelites}")
        print(f"Masa (kg): {self.masa}")
        print(f"Volumen (km³): {self.volumen}")
        print(f"Diámetro (km): {self.diametro}")
        print(f"Distancia al Sol (millones km): {self.distancia_sol}")
        print(f"Tipo: {self.tipo_planeta.name}")
        print(f"Observable: {self.es_observable}")

    def calcular_densidad(self):
        if self.volumen == 0:
            return 0
        return self.masa / self.volumen

    def es_planeta_exterior(self):
        distancia_km = self.distancia_sol * 1_000_000
        distancia_ua = distancia_km / Planeta.UA
        return distancia_ua > 3.4


# ------------------ MAIN ------------------

if __name__ == "__main__":

    planetas = []

    for i in range(2):
        print(f"\nIngrese los datos del planeta {i+1}")

        nombre = input("Nombre: ")
        satelites = int(input("Cantidad de satélites: "))
        masa = float(input("Masa (kg): "))
        volumen = float(input("Volumen (km³): "))
        diametro = int(input("Diámetro (km): "))
        distancia = int(input("Distancia al Sol (millones km): "))

        print("Tipo de planeta: 1=GASEOSO, 2=TERRESTRE, 3=ENANO")
        tipo_opcion = int(input("Seleccione el tipo: "))
        tipo = TipoPlaneta(tipo_opcion)

        observable = input("¿Es observable a simple vista? (true/false): ").lower() == "true"

        planeta = Planeta(nombre, satelites, masa, volumen,
                          diametro, distancia, tipo, observable)

        planetas.append(planeta)

    # Mostrar resultados
    for planeta in planetas:
        planeta.imprimir()
        print("Densidad:", planeta.calcular_densidad())
        print("¿Es planeta exterior?", planeta.es_planeta_exterior())
# Out:
# Ingrese los datos del planeta 1
# Nombre: Tierra
# Cantidad de satélites: 1
# Masa (kg): 5.9736E24
# Volumen (km³): 1.08321E12
# Diámetro (km): 12742
# Distancia al Sol (millones km): 150000000
# Tipo de planeta: 1=GASEOSO, 2=TERRESTRE, 3=ENANO
# Seleccione el tipo: 2
# ¿Es observable a simple vista? (true/false): true
#
# Ingrese los datos del planeta 2
# Nombre: Jupiter
# Cantidad de satélites: 79
# Masa (kg): 1.899E27
# Volumen (km³): 1.4313E15
# Diámetro (km): 139820
# Distancia al Sol (millones km): 750000000
# Tipo de planeta: 1=GASEOSO, 2=TERRESTRE, 3=ENANO
# Seleccione el tipo: 1
# ¿Es observable a simple vista? (true/false): true
#
# Planeta: Tierra
# Satélites: 1
# Masa (kg): 5.9736e+24
# Volumen (km³): 1083210000000.0
# Diámetro (km): 12742
# Distancia al Sol (millones km): 150000000
# Tipo: TERRESTRE
# Observable: True
# Densidad: 5514720137369.484
# ¿Es planeta exterior? True
#
# Planeta: Jupiter
# Satélites: 79
# Masa (kg): 1.899e+27
# Volumen (km³): 1431300000000000.0
# ...

# %% [markdown]
# # <font color=#B375E6 size=6>**Ejercicio 2.3. Estado de un objeto**</font>

# %% [markdown]
# Se requiere un programa que modele el concepto de un automóvil. Un automóvil tiene los siguientes atributos:
# * Marca: el nombre del fabricante.
# * Modelo: año de fabricación.
# * Motor: volumen en litros del cilindraje del motor de un automóvil.
# * Tipo de combustible: valor enumerado con los posibles valores de gasolina, bioetanol, diésel, biodiésel, gas natural.
# * Tipo de automóvil: valor enumerado con los posibles valores de carro de ciudad, subcompacto, compacto, familiar, ejecutivo, SUV.
# * Número de puertas: cantidad de puertas.
# * Cantidad de asientos: número de asientos disponibles que tiene el vehículo.
# * Velocidad máxima: velocidad máxima sostenida por el vehículo en km/h.
# * Color: valor enumerado con los posibles valores de blanco, negro, rojo, naranja, amarillo, verde, azul, violeta.
# * Velocidad actual: velocidad del vehículo en un momento dado.
#
# La clase debe incluir los siguientes métodos:
#
# * Un constructor para la clase Automóvil donde se le pasen como parámetros los valores de sus atributos. u Métodos get y set para la clase Automóvil.
# * Métodos para acelerar una cierta velocidad, desacelerar y frenar (colocar la velocidad actual en cero). Es importante tener en cuenta que no se debe acelerar más allá de la velocidad máxima permitida para el automóvil. De igual manera, tampoco es posible desacelerar a una velocidad negativa. Si se cumplen estos casos, se debe mostrar por pantalla los mensajes correspondientes.
# * Un método para calcular el tiempo estimado de llegada, utilizando como parámetro la distancia a recorrer en kilómetros. El tiempo estimado se calcula como el cociente entre la distancia a recorrer y la velocidad actual.
# * Un método para mostrar los valores de los atributos de un Automóvil en pantalla.
# * Un método main donde se deben crear un automóvil, colocar su velocidad actual en 100 km/h, aumentar su velocidad en 20 km/h, luego decrementar su velocidad en 50 km/h, y después frenar. Con cada cambio de velocidad, se debe mostrar en pantalla la velocidad actual.

# %%
from enum import Enum


# ---------------- ENUMERACIONES ----------------

class TipoCombustible(Enum):
    GASOLINA = 1
    BIOETANOL = 2
    DIESEL = 3
    BIODIESEL = 4
    GAS_NATURAL = 5


class TipoAutomovil(Enum):
    CIUDAD = 1
    SUBCOMPACTO = 2
    COMPACTO = 3
    FAMILIAR = 4
    EJECUTIVO = 5
    SUV = 6


class Color(Enum):
    BLANCO = 1
    NEGRO = 2
    ROJO = 3
    NARANJA = 4
    AMARILLO = 5
    VERDE = 6
    AZUL = 7
    VIOLETA = 8


# ---------------- CLASE AUTOMOVIL ----------------

class Automovil:

    def __init__(self, marca, modelo, motor, tipo_combustible,
                 tipo_automovil, numero_puertas, cantidad_asientos,
                 velocidad_maxima, color):

        self.marca = marca
        self.modelo = modelo
        self.motor = motor
        self.tipo_combustible = tipo_combustible
        self.tipo_automovil = tipo_automovil
        self.numero_puertas = numero_puertas
        self.cantidad_asientos = cantidad_asientos
        self.velocidad_maxima = velocidad_maxima
        self.color = color
        self.velocidad_actual = 0

    def get_velocidad_actual(self):
        return self.velocidad_actual

    def set_velocidad_actual(self, velocidad):
        if 0 <= velocidad <= self.velocidad_maxima:
            self.velocidad_actual = velocidad
        else:
            print("Velocidad fuera de rango permitido.")

    def acelerar(self, incremento):
        if self.velocidad_actual + incremento > self.velocidad_maxima:
            print("No se puede superar la velocidad máxima.")
            self.velocidad_actual = self.velocidad_maxima
        else:
            self.velocidad_actual += incremento

    def desacelerar(self, decremento):
        if self.velocidad_actual - decremento < 0:
            print("No se puede tener velocidad negativa.")
            self.velocidad_actual = 0
        else:
            self.velocidad_actual -= decremento

    def frenar(self):
        self.velocidad_actual = 0

    def calcular_tiempo_llegada(self, distancia):
        if self.velocidad_actual == 0:
            return "El automóvil está detenido."
        return distancia / self.velocidad_actual

    def imprimir(self):
        print("\n--- DATOS DEL AUTOMÓVIL ---")
        print("Marca:", self.marca)
        print("Modelo:", self.modelo)
        print("Motor:", self.motor, "L")
        print("Tipo combustible:", self.tipo_combustible.name)
        print("Tipo automóvil:", self.tipo_automovil.name)
        print("Puertas:", self.numero_puertas)
        print("Asientos:", self.cantidad_asientos)
        print("Velocidad máxima:", self.velocidad_maxima, "km/h")
        print("Color:", self.color.name)
        print("Velocidad actual:", self.velocidad_actual, "km/h")


# ---------------- MAIN ----------------

if __name__ == "__main__":

    print("Ingrese los datos del automóvil:\n")

    marca = input("Marca: ")
    modelo = int(input("Modelo (año): "))
    motor = float(input("Motor (litros): "))

    print("\nTipo de combustible:")
    for tipo in TipoCombustible:
        print(tipo.value, "-", tipo.name)
    tipo_comb = TipoCombustible(int(input("Seleccione una opción: ")))

    print("\nTipo de automóvil:")
    for tipo in TipoAutomovil:
        print(tipo.value, "-", tipo.name)
    tipo_auto = TipoAutomovil(int(input("Seleccione una opción: ")))

    numero_puertas = int(input("Número de puertas: "))
    cantidad_asientos = int(input("Cantidad de asientos: "))
    velocidad_maxima = int(input("Velocidad máxima (km/h): "))

    print("\nColor:")
    for c in Color:
        print(c.value, "-", c.name)
    color = Color(int(input("Seleccione una opción: ")))

    auto = Automovil(marca, modelo, motor, tipo_comb,
                     tipo_auto, numero_puertas,
                     cantidad_asientos, velocidad_maxima, color)

    auto.imprimir()

    # Secuencia solicitada
    auto.set_velocidad_actual(100)
    print("\nVelocidad actual:", auto.get_velocidad_actual(), "km/h")

    auto.acelerar(20)
    print("Después de acelerar 20 km/h:", auto.get_velocidad_actual(), "km/h")

    auto.desacelerar(50)
    print("Después de desacelerar 50 km/h:", auto.get_velocidad_actual(), "km/h")

    auto.frenar()
    print("Después de frenar:", auto.get_velocidad_actual(), "km/h")
# Out:
# Ingrese los datos del automóvil:
#
# Marca: ford
# Modelo (año): 2018
# Motor (litros): 3
#
# Tipo de combustible:
# 1 - GASOLINA
# 2 - BIOETANOL
# 3 - DIESEL
# 4 - BIODIESEL
# 5 - GAS_NATURAL
# Seleccione una opción: 3
#
# Tipo de automóvil:
# 1 - CIUDAD
# 2 - SUBCOMPACTO
# 3 - COMPACTO
# 4 - FAMILIAR
# 5 - EJECUTIVO
# 6 - SUV
# Seleccione una opción: 5
# Número de puertas: 5
# Cantidad de asientos: 6
# Velocidad máxima (km/h): 250
#
# Color:
# 1 - BLANCO
# 2 - NEGRO
# 3 - ROJO
# 4 - NARANJA
# 5 - AMARILLO
# 6 - VERDE
# 7 - AZUL
# 8 - VIOLETA
# Seleccione una opción: 2
#
# --- DATOS DEL AUTOMÓVIL ---
# Marca: ford
# Modelo: 2018
# Motor: 3.0 L
# Tipo combustible: DIESEL
# Tipo automóvil: EJECUTIVO
# Puertas: 5
# Asientos: 6
# Velocidad máxima: 250 km/h
# Color: NEGRO
# Velocidad actual: 0 km/h
#
# Velocidad actual: 100 km/h
# Después de acelerar 20 km/h: 120 km/h
# Después de desacelerar 50 km/h: 70 km/h
# Después de frenar: 0 km/h

# %% [markdown]
# # <font color=#B375E6 size=6 >**Ejercicio 2.4: Clases sobre figuras geométricas**</font>
#
# Se requiere un programa que modele varias figuras geométricas: el círculo, el rectángulo, el cuadrado y el triángulo rectángulo.
#
# \
# ‣  El círculo tiene como atributo su radio en centímetros
#
# ‣  El rectángulo, su base y altura en centímetros
#
# ‣  El cuadrado, la longitud de sus lados en centímetros.
#
# ‣ El triángulo, su base y altura en centímetros.
#
#
#
#
# \
# Se requieren métodos para determinar el área y el perímetro de cada figura geométrica. Además, para el triángulo rectángulo se requiere
#
# \
# ‣ Un método que calcule la hipotenusa del rectángulo
#
# ‣ Un método para determinar qué tipo de triángulo es:
#
# *   Equilátero: todos sus lados son iguales Isósceles: tiene dos lados iguales.
#
# *   Escaleno: todos sus lados son diferentes
#
# \
# Se debe desarrollar una clase de prueba con un método main para crear las cuatro figuras y probar los métodos respectivos.

# %%
import math

# Clase Circulo

class Circulo:
    def __init__(self, radio):
        self.radio = float(radio)

    def area(self):
        return math.pi * math.pow(self.radio, 2)

    def perimetro(self):
        return 2 * math.pi * self.radio


# Clase Rectangulo

class Rectangulo:
    def __init__(self, base, altura):
        self.base = float(base)
        self.altura = float(altura)

    def area(self):
        return self.base * self.altura

    def perimetro(self):
        return 2 * (self.base + self.altura)


# Clase Cuadrado

class Cuadrado:
    def __init__(self, lado):
        self.lado = float(lado)

    def area(self):
        return math.pow(self.lado, 2)

    def perimetro(self):
        return 4 * self.lado


# Clase TrianguloRectangulo

class TrianguloRectangulo:
    def __init__(self, base, altura):
        self.base = float(base)
        self.altura = float(altura)

    def area(self):
        return (self.base * self.altura) / 2

    def hipotenusa(self):
        return math.sqrt(math.pow(self.base, 2) + math.pow(self.altura, 2))

    def perimetro(self):
        return self.base + self.altura + self.hipotenusa()

    def tipo_triangulo(self):
        lado1 = self.base
        lado2 = self.altura
        lado3 = self.hipotenusa()

        if lado1 == lado2 == lado3:
            return "Equilátero"
        elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
            return "Isósceles"
        else:
            return "Escaleno"


# Clase de Prueba

class PruebaFiguras:

    @staticmethod
    def main():

        print("===== REGISTRO DE FIGURAS GEOMÉTRICAS =====\n")

        # CÍRCULO
        radio = float(input("Ingrese el radio del círculo: "))
        circulo = Circulo(radio)

        print("\n--- CÍRCULO ---")
        print("Área:", circulo.area())
        print("Perímetro:", circulo.perimetro())

        # RECTÁNGULO
        base_rect = float(input("\nIngrese la base del rectángulo: "))
        altura_rect = float(input("Ingrese la altura del rectángulo: "))
        rectangulo = Rectangulo(base_rect, altura_rect)

        print("\n--- RECTÁNGULO ---")
        print("Área:", rectangulo.area())
        print("Perímetro:", rectangulo.perimetro())

        # CUADRADO
        lado = float(input("\nIngrese el lado del cuadrado: "))
        cuadrado = Cuadrado(lado)

        print("\n--- CUADRADO ---")
        print("Área:", cuadrado.area())
        print("Perímetro:", cuadrado.perimetro())

        # TRIÁNGULO RECTÁNGULO
        base_tri = float(input("\nIngrese la base del triángulo rectángulo: "))
        altura_tri = float(input("Ingrese la altura del triángulo rectángulo: "))
        triangulo = TrianguloRectangulo(base_tri, altura_tri)

        print("\n--- TRIÁNGULO RECTÁNGULO ---")
        print("Área:", triangulo.area())
        print("Hipotenusa:", triangulo.hipotenusa())
        print("Perímetro:", triangulo.perimetro())
        print("Tipo de triángulo:", triangulo.tipo_triangulo())


# Ejecutar programa
if __name__ == "__main__":
    PruebaFiguras.main()
# Out:
# ===== REGISTRO DE FIGURAS GEOMÉTRICAS =====
#
# Ingrese el radio del círculo: 5
#
# --- CÍRCULO ---
# Área: 78.53981633974483
# Perímetro: 31.41592653589793
#
# Ingrese la base del rectángulo: 3
# Ingrese la altura del rectángulo: 5
#
# --- RECTÁNGULO ---
# Área: 15.0
# Perímetro: 16.0
#
# Ingrese el lado del cuadrado: 5
#
# --- CUADRADO ---
# Área: 25.0
# Perímetro: 20.0
#
# Ingrese la base del triángulo rectángulo: 5
# Ingrese la altura del triángulo rectángulo: 7
#
# --- TRIÁNGULO RECTÁNGULO ---
# Área: 17.5
# Hipotenusa: 8.602325267042627
# Perímetro: 20.602325267042627
# Tipo de triángulo: Escaleno

# %% [markdown]
# # <font color=#B375E6 size=6>**Ejercicio 2.5: clase CuentaBancaria**</font>
#
# Se requiere un programa que modele una cuenta bancaria que posee los
# siguientes atributos:
#
# \
# ‣ Nombres del titular.
#
#
# ‣ Apellidos del titular.
#
#
# ‣ Número de la cuenta bancaria
#
#
# ‣ Tipo de cuenta: puede ser una cuenta de ahorros o una cuenta
# corriente.
#
#
# ‣ Saldo de la cuenta
#
# \
# Se debe definir un constructor que inicialice los atributos de la clase
# Cuando se crea una cuenta bancaria, su saldo inicial tiene un valor de cero.
#
# \
# En una determinada cuenta bancaria se puede:
#
# \
# ‣ Imprimir por pantalla los valores de los atributos de una cuenta
# bancaria.
#
#
# ‣ Consultar el saldo de una cuenta bancaria.
#
#
# ‣ Consignar un determinado valor en la cuenta bancaria, actualizando el saldo correspondiente.
#
#
# ‣ Retirar un determinado valor de la cuenta bancaria, actualizando
# el saldo correspondiente. Es necesario tener en cuenta que no se
# puede realizar el retiro si el valor solicitado supera el saldo actual
# de la cuenta

# %%
# Clase CuentaBancaria

class CuentaBancaria:

    def __init__(self, nombres, apellidos, numero_cuenta, tipo_cuenta):
        self.nombres = nombres
        self.apellidos = apellidos
        self.numero_cuenta = numero_cuenta
        self.tipo_cuenta = tipo_cuenta
        self.saldo = 0.0  # Saldo inicial en cero

    # Mostrar datos de la cuenta
    def mostrar_datos(self):
        print("\n===== DATOS DE LA CUENTA =====")
        print("Titular:", self.nombres, self.apellidos)
        print("Número de cuenta:", self.numero_cuenta)
        print("Tipo de cuenta:", self.tipo_cuenta)
        print("Saldo actual:", self.saldo)

    # Consultar saldo
    def consultar_saldo(self):
        print("Saldo disponible:", self.saldo)

    # Consignar dinero
    def consignar(self, monto):
        if monto > 0:
            self.saldo += monto
            print("Consignación realizada con éxito.")
            print("Nuevo saldo:", self.saldo)
        else:
            print("El monto debe ser mayor que cero.")

    # Retirar dinero
    def retirar(self, monto):
        if monto <= 0:
            print("El monto debe ser mayor que cero.")
        elif monto > self.saldo:
            print("Fondos insuficientes. No se puede realizar el retiro.")
        else:
            self.saldo -= monto
            print("Retiro realizado con éxito.")
            print("Nuevo saldo:", self.saldo)


# Programa principal

def main():

    print("===== CREACIÓN DE CUENTA BANCARIA =====")

    nombres = input("Ingrese los nombres del titular: ")
    apellidos = input("Ingrese los apellidos del titular: ")
    numero_cuenta = input("Ingrese el número de cuenta: ")
    tipo_cuenta = input("Ingrese el tipo de cuenta (Ahorros/Corriente): ")

    cuenta = CuentaBancaria(nombres, apellidos, numero_cuenta, tipo_cuenta)

    while True:
        print("\n===== MENÚ =====")
        print("1. Mostrar datos de la cuenta")
        print("2. Consultar saldo")
        print("3. Consignar dinero")
        print("4. Retirar dinero")
        print("5. Salir")

        opcion = input("Seleccione una opción: ")

        if opcion == "1":
            cuenta.mostrar_datos()

        elif opcion == "2":
            cuenta.consultar_saldo()

        elif opcion == "3":
            monto = float(input("Ingrese el monto a consignar: "))
            cuenta.consignar(monto)

        elif opcion == "4":
            monto = float(input("Ingrese el monto a retirar: "))
            cuenta.retirar(monto)

        elif opcion == "5":
            print("Gracias por usar el sistema bancario.")
            break

        else:
            print("Opción inválida. Intente nuevamente.")


if __name__ == "__main__":
    main()
# Out:
# ===== CREACIÓN DE CUENTA BANCARIA =====
# Ingrese los nombres del titular: Susana
# Ingrese los apellidos del titular: Horia
# Ingrese el número de cuenta: 43892031
# Ingrese el tipo de cuenta (Ahorros/Corriente): Ahorros
#
# ===== MENÚ =====
# 1. Mostrar datos de la cuenta
# 2. Consultar saldo
# 3. Consignar dinero
# 4. Retirar dinero
# 5. Salir
# Seleccione una opción: 1
#
# ===== DATOS DE LA CUENTA =====
# Titular: Susana Horia
# Número de cuenta: 43892031
# Tipo de cuenta: Ahorros
# Saldo actual: 0.0
#
# ===== MENÚ =====
# 1. Mostrar datos de la cuenta
# 2. Consultar saldo
# 3. Consignar dinero
# 4. Retirar dinero
# 5. Salir
# Seleccione una opción: 2
# Saldo disponible: 0.0
#
# ===== MENÚ =====
# 1. Mostrar datos de la cuenta
# 2. Consultar saldo
# 3. Consignar dinero
# 4. Retirar dinero
# 5. Salir
# Seleccione una opción: 3
# Ingrese el monto a consignar: 45600
# Consignación realizada con éxito.
# Nuevo saldo: 45600.0
#
# ===== MENÚ =====
# 1. Mostrar datos de la cuenta
# ...
